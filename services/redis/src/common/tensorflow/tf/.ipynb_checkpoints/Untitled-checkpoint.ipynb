# %%
# !echo $(python --version)
# !echo $(pip --version)
# Out:
# Python 3.6.9
# pip 19.3.1 from /usr/local/lib/python3.6/dist-packages/pip (python 3.6)

# %%
# %matplotlib inline

# %%
#!catalyst ingest-exchange -x binance -f daily
#!catalyst ingest-exchange -x binance -f minute

# %%
# !catalyst ingest-exchange -x binance -f minute -i ada_usdt
# !catalyst ingest-exchange -x binance -f minute -i algo_usdt
# !catalyst ingest-exchange -x binance -f minute -i ankr_usdt
#!catalyst ingest-exchange -x binance -f minute -i atom_usdt
# !catalyst ingest-exchange -x binance -f minute -i band_usdt
# !catalyst ingest-exchange -x binance -f minute -i bat_usdt
# !catalyst ingest-exchange -x binance -f minute -i beam_usdt
# !catalyst ingest-exchange -x binance -f minute -i bnb_usdt
# !catalyst ingest-exchange -x binance -f minute -i btc_usdt
# !catalyst ingest-exchange -x binance -f minute -i btt_usdt
# Out:
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i busd_usdt
# !catalyst ingest-exchange -x binance -f minute -i celr_usdt
# !catalyst ingest-exchange -x binance -f minute -i chz_usdt
# !catalyst ingest-exchange -x binance -f minute -i cocos_usdt
# !catalyst ingest-exchange -x binance -f minute -i cos_usdt
# !catalyst ingest-exchange -x binance -f minute -i cvc_usdt
# !catalyst ingest-exchange -x binance -f minute -i dash_usdt
# !catalyst ingest-exchange -x binance -f minute -i dent_usdt
# !catalyst ingest-exchange -x binance -f minute -i dock_usdt
# !catalyst ingest-exchange -x binance -f minute -i doge_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i dusk_usdt
# !catalyst ingest-exchange -x binance -f minute -i enj_usdt
# !catalyst ingest-exchange -x binance -f minute -i eos_usdt
# !catalyst ingest-exchange -x binance -f minute -i erd_usdt
# !catalyst ingest-exchange -x binance -f minute -i etc_usdt
# !catalyst ingest-exchange -x binance -f minute -i eth_usdt
# !catalyst ingest-exchange -x binance -f minute -i fet_usdt
# !catalyst ingest-exchange -x binance -f minute -i ftm_usdt
# !catalyst ingest-exchange -x binance -f minute -i fun_usdt
# !catalyst ingest-exchange -x binance -f minute -i gto_usdt
#!catalyst ingest-exchange -x binance -f minute -i hbar_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i hc_usdt
# !catalyst ingest-exchange -x binance -f minute -i hot_usdt
# !catalyst ingest-exchange -x binance -f minute -i icx_usdt
# !catalyst ingest-exchange -x binance -f minute -i iost_usdt
# !catalyst ingest-exchange -x binance -f minute -i iota_usdt
# !catalyst ingest-exchange -x binance -f minute -i kava_usdt
# !catalyst ingest-exchange -x binance -f minute -i key_usdt
# !catalyst ingest-exchange -x binance -f minute -i link_usdt
# !catalyst ingest-exchange -x binance -f minute -i ltc_usdt
# !catalyst ingest-exchange -x binance -f minute -i matic_usdt
# !catalyst ingest-exchange -x binance -f minute -i mft_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i mith_usdt
# !catalyst ingest-exchange -x binance -f minute -i mtl_usdt
# !catalyst ingest-exchange -x binance -f minute -i nano_usdt
# !catalyst ingest-exchange -x binance -f minute -i neo_usdt
# !catalyst ingest-exchange -x binance -f minute -i nkn_usdt
# !catalyst ingest-exchange -x binance -f minute -i npxs_usdt
# !catalyst ingest-exchange -x binance -f minute -i nuls_usdt
# !catalyst ingest-exchange -x binance -f minute -i omg_usdt
# !catalyst ingest-exchange -x binance -f minute -i one_usdt
# !catalyst ingest-exchange -x binance -f minute -i ong_usdt
# !catalyst ingest-exchange -x binance -f minute -i ont_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i pax_usdt
# !catalyst ingest-exchange -x binance -f minute -i perl_usdt
# !catalyst ingest-exchange -x binance -f minute -i qtum_usdt
# !catalyst ingest-exchange -x binance -f minute -i ren_usdt
# !catalyst ingest-exchange -x binance -f minute -i rvn_usdt
# !catalyst ingest-exchange -x binance -f minute -i storm_usdt
# !catalyst ingest-exchange -x binance -f minute -i stx_usdt
# !catalyst ingest-exchange -x binance -f minute -i tfuel_usdt
# !catalyst ingest-exchange -x binance -f minute -i theta_usdt
# !catalyst ingest-exchange -x binance -f minute -i tomo_usdt
# !catalyst ingest-exchange -x binance -f minute -i trx_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i tusd_usdt
# !catalyst ingest-exchange -x binance -f minute -i usdc_usdt
# !catalyst ingest-exchange -x binance -f minute -i usds_usdt
# !catalyst ingest-exchange -x binance -f minute -i vet_usdt
# !catalyst ingest-exchange -x binance -f minute -i wan_usdt
# !catalyst ingest-exchange -x binance -f minute -i waves_usdt
# !catalyst ingest-exchange -x binance -f minute -i win_usdt
# !catalyst ingest-exchange -x binance -f minute -i xlm_usdt
# !catalyst ingest-exchange -x binance -f minute -i xmr_usdt
# !catalyst ingest-exchange -x binance -f minute -i xrp_usdt
# !catalyst ingest-exchange -x binance -f minute -i xtz_usdt
# !catalyst ingest-exchange -x binance -f minute -i zec_usdt
# !catalyst ingest-exchange -x binance -f minute -i zil_usdt
# !catalyst ingest-exchange -x binance -f minute -i zrx_usdt
# Out:
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# import pyfolio as pf

from catalyst.utils.run_algo import run_algorithm
from catalyst.api import order_target_percent, record, symbol
from catalyst.exchange.utils.exchange_utils import get_exchange_symbols

# %%
BASE_CAPITAL = 1000
BASE_CURRENCY = 'usdt'
EXCHANGE_NAME = 'binance'
START_DATE = '2019-11-01'
END_DATE = '2019-12-01'
FREQUENCY = '1H' # 1T (minutes), 1H (hours) or 1D (days).
API_FREQUENCY = FREQUENCY == '1D' and 'daily' or 'minute'
SHORT_EMA_LENGTH = 5
LONG_EMA_LENGTH = 20
DISABLED_MARKETS = [
    'atom_usdt',
    'hbar_usdt'
]

# %%
# TODO: Document properly.
def datetime_date(datetime):
    return datetime.strftime('%Y-%m-%d')

# %%
def get_market_label(market_key):
    """Get a label from a market key.

    Parameters
    ----------
    market_key : str
        The market key to format.

    Returns
    -------
    market_label : str
        The market_key formatted as a label.
    """

    return market_key.upper().split('_')[0]

# %%
def frequency_in_minutes(frequency):
    """Get the frequency as an amount of minutes.

    Parameters
    ----------
    frequency : str
        1T (minutes), 1H (hours) or 1D (days).

    Returns
    -------
    frequency_minutes : int
        The frequency expressed as an amount of minutes.
    """

    if frequency == '1T':
        return 1
    elif frequency == '1H':
        return 60
    elif frequency == '1D':
        return 60 * 24

# %%
def initialize(context):
    """Initializes the backtest.

    Parameters
    ----------
    context : catalyst.ExchangeTradingAlgorithmBacktest
        The backtest object. This is used as shared state and to collect results.
    """

    context.i = -1
    context.exchange = 'binance'
    context.quote_currency = BASE_CURRENCY
    context.frequency = FREQUENCY
    context.loop_interval = FREQUENCY == '1D' and 1 or frequency_in_minutes(FREQUENCY)
    context.short_sma_length = SHORT_EMA_LENGTH
    context.short_sma_frequency = FREQUENCY
    context.long_sma_length = LONG_EMA_LENGTH
    context.long_sma_frequency = FREQUENCY
    context.universe = universe(
        context,
        datetime_date(context.sim_params.start_session),
        datetime_date(context.sim_params.end_session)
    )

    print('Universe Size: %s' % (len(context.universe)))

# %%
# TODO: Document properly.
def universe(context, start_date, end_date):
    """Returns a list of symbols to trade."""
    
    # get all the pairs for the given exchange
    json_symbols = get_exchange_symbols(context.exchange)

    # convert into a DataFrame for easier processing
    df = pd.DataFrame.from_dict(json_symbols).transpose().astype(str)
    df['quote_currency'] = df.apply(
        lambda row: row.symbol.split('_')[1],
        axis=1
    )
    df['base_currency'] = df.apply(
        lambda row: row.symbol.split('_')[0],
        axis=1
    )
    
    # print('universe df all pairs %s %s' % (len(df), df.symbol.tolist()))

    # Filter all the pairs to get only the ones for a given quote_currency
    df = df[df['quote_currency'] == context.quote_currency]
    
    # print('universe df quote pairs %s %s' % (len(df), df.symbol.tolist()))
    # print('universe df too late pairs %s %s' % (len(df[df.start_date < start_date]), df[df.start_date < start_date].symbol.tolist()))
    # print('universe df too early pairs %s %s' % (len(df[df.end_daily > end_date]), df[df.end_daily > end_date].symbol.tolist()))

    # Filter all pairs to ensure that pair existed in the current date range
    df = df[df.start_date < start_date]
    df = df[df.end_daily > end_date]

    # print('universe df after dates end: %s' % (len(df)))
    
    filtered_universe = [x for x in df.symbol.tolist() if x not in DISABLED_MARKETS]

    # print('universe df after filter: %s' % (len(df)))
    
    for x in filtered_universe:
        print(x)

    return filtered_universe

# %%
# TODO: Document properly.
def analyze(context, results):
    """Analyzes the results when the backtest is done."""

    fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(8, 12))

    results[['cash']].plot(ax=ax1)
    ax1.set_xlabel('')
    ax1.set_ylabel('')
    ax1.legend(['Cash (BTC)'])

    results[['returns']].plot(ax=ax2)
    ax2.set_xlabel('')
    ax2.set_ylabel('')
    ax2.legend(['Returns (BTC)'])

    # plt.subplots_adjust(hspace=2.0)
    plt.tight_layout()
    plt.show()

# %%
def recalculate(context, bar_data):
    """Returns the values for the algorithm for each Asset for this Bar.

    Parameters
    ----------
    context : di
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    context.values = {}

    for market_key in context.universe:
        market_symbol = symbol(market_key)

        # Get the current price.
        price_value = bar_data.current(market_symbol, 'price')

        # Calculate the Short SMA.
        short_sma_data = bar_data.history(
            market_symbol,
            'price',
            bar_count=context.short_sma_length,
            frequency=context.short_sma_frequency,
        )
        short_sma_value = short_sma_data.mean()

        # Calculate the Long SMA.
        long_sma_data = bar_data.history(
            market_symbol,
            'price',
            bar_count=context.long_sma_length,
            frequency=context.long_sma_frequency,
        )
        long_sma_value = long_sma_data.mean()

        # Save data per market in the context.
        context.values[market_key] = {
            'price': price_value,
            'short_sma': short_sma_value,
            'long_sma': long_sma_value,
        }

# %%
def rebalance(context, bar_data):
    """Opens Buy and Sell orders and closes orders for this Bar.

    Parameters
    ----------
    context : catalyst.exchange.exchange_algorithm.ExchangeTradingAlgorithmBacktest
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    # Wait until all orders are executed before considering more trades.
    orders = context.blotter.open_orders
    if len(orders) > 0:
        return

    total_symbols = 0
    open_market_symbols = []
    close_market_symbols = []

    for market_key in context.universe:
        market_symbol = symbol(market_key)

        # Exit if we cannot trade.
        if not bar_data.can_trade(market_symbol):
            return

        # We check what's our position on our portfolio and trade accordingly.
        market = context.values[market_key]

        if market['short_sma'] > market['long_sma']:
            open_market_symbols.append(market_symbol)
        elif market['short_sma'] < market['long_sma']:
            close_market_symbols.append(market_symbol)
        
        total_symbols = total_symbols + 1

    for market_symbol in close_market_symbols:
        if context.portfolio.positions[market_symbol].amount > 0:
            order_target_percent(market_symbol, 0)
    
    for market_symbol in open_market_symbols:
        order_target_percent(market_symbol, 1 / total_symbols)

    print("Total: %s, Open: %s, Close: %s" % (total_symbols, len(open_market_symbols), len(close_market_symbols)))

# %%
def handle_data(context, bar_data):
    """Get the frequency as an amount of minutes.

    Parameters
    ----------
    context : catalyst.exchange.exchange_algorithm.ExchangeTradingAlgorithmBacktest
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    context.i += 1

    # We need a minimum of LONG_EMA_LENGTH bars to calculate.
    if context.i < context.long_sma_length:
        return

    if context.i % context.loop_interval != 0:
        return

    current_date = bar_data.current_dt

    print("%s %s" % (context.i, current_date))

    recalculate(context, bar_data)
    rebalance(context, bar_data)

    # Save columns for Performance.
    record(
        cash=context.portfolio.cash,
        returns=context.portfolio.returns,
    )

# %%
algorithm_results = run_algorithm(
    capital_base=BASE_CAPITAL,
    start=pd.to_datetime(START_DATE, utc=True),
    end=pd.to_datetime(END_DATE, utc=True),
    initialize=initialize,
    handle_data=handle_data,
    analyze=analyze,
    data_frequency=API_FREQUENCY,
    live=False,
    exchange_name=EXCHANGE_NAME,
    quote_currency=BASE_CURRENCY,
    algo_namespace='test',
    live_graph=False
)

#returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(algorithm_results)
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')
# Out:
# [2019-12-05 18:09:59.924754] INFO: run_algo: Catalyst version 0.5.21
# [2019-12-05 18:09:59.925561] WARNING: run_algo: Catalyst is currently in ALPHA. It is going through rapid development and it is subject to errors. Please use carefully. We encourage you to report any issue on GitHub: https://github.com/enigmampc/catalyst/issues
# [2019-12-05 18:10:02.927353] INFO: run_algo: running algo in backtest mode
# [2019-12-05 18:10:03.492743] INFO: exchange_algorithm: initialized trading algorithm in backtest mode
# ada_usdt
# algo_usdt
# ankr_usdt
# band_usdt
# bat_usdt
# beam_usdt
# bnb_usdt
# btc_usdt
# btt_usdt
# busd_usdt
# celr_usdt
# chz_usdt
# cocos_usdt
# cos_usdt
# cvc_usdt
# dash_usdt
# dent_usdt
# dock_usdt
# doge_usdt
# dusk_usdt
# enj_usdt
# eos_usdt
# erd_usdt
# etc_usdt
# eth_usdt
# fet_usdt
# ftm_usdt
# fun_usdt
# gto_usdt
# hc_usdt
# hot_usdt
# icx_usdt
# iost_usdt
# iota_usdt
# kava_usdt
# key_usdt
# link_usdt
# ltc_usdt
# matic_usdt
# mft_usdt
# mith_usdt
# mtl_usdt
# nano_usdt
# neo_usdt
# nkn_usdt
# npxs_usdt
# nuls_usdt
# omg_usdt
# one_usdt
# ong_usdt
# ont_usdt
# pax_usdt
# perl_usdt
# qtum_usdt
# ren_usdt
# rvn_usdt
# storm_usdt
# stx_usdt
# tfuel_usdt
# theta_usdt
# tomo_usdt
# trx_usdt
# tusd_usdt
# usdc_usdt
# usds_usdt
# vet_usdt
# wan_usdt
# waves_usdt
# win_usdt
# xlm_usdt
# xmr_usdt
# xrp_usdt
# xtz_usdt
# zec_usdt
# zil_usdt
# zrx_usdt
# Universe Size: 76
# 20 2019-11-01 00:20:00+00:00
# 21 2019-11-01 00:21:00+00:00
# 22 2019-11-01 00:22:00+00:00
# 23 2019-11-01 00:23:00+00:00
# 24 2019-11-01 00:24:00+00:00
# 25 2019-11-01 00:25:00+00:00
# 26 2019-11-01 00:26:00+00:00
# 27 2019-11-01 00:27:00+00:00
# 28 2019-11-01 00:28:00+00:00
# 29 2019-11-01 00:29:00+00:00
# 30 2019-11-01 00:30:00+00:00
# 31 2019-11-01 00:31:00+00:00
# 32 2019-11-01 00:32:00+00:00
# 33 2019-11-01 00:33:00+00:00
# 34 2019-11-01 00:34:00+00:00
# 35 2019-11-01 00:35:00+00:00
# 36 2019-11-01 00:36:00+00:00
# 37 2019-11-01 00:37:00+00:00
# 38 2019-11-01 00:38:00+00:00
# 39 2019-11-01 00:39:00+00:00
# 40 2019-11-01 00:40:00+00:00
# 41 2019-11-01 00:41:00+00:00
# 42 2019-11-01 00:42:00+00:00
# 43 2019-11-01 00:43:00+00:00
# 44 2019-11-01 00:44:00+00:00
# 45 2019-11-01 00:45:00+00:00
# 46 2019-11-01 00:46:00+00:00
# 47 2019-11-01 00:47:00+00:00
# 48 2019-11-01 00:48:00+00:00
# 49 2019-11-01 00:49:00+00:00
# 50 2019-11-01 00:50:00+00:00
# 51 2019-11-01 00:51:00+00:00
# 52 2019-11-01 00:52:00+00:00
# 53 2019-11-01 00:53:00+00:00
# 54 2019-11-01 00:54:00+00:00
# 55 2019-11-01 00:55:00+00:00
# 56 2019-11-01 00:56:00+00:00
# 57 2019-11-01 00:57:00+00:00
# 58 2019-11-01 00:58:00+00:00
# 59 2019-11-01 00:59:00+00:00
# 60 2019-11-01 01:00:00+00:00
# 61 2019-11-01 01:01:00+00:00
# 62 2019-11-01 01:02:00+00:00
# 63 2019-11-01 01:03:00+00:00
# 663 2019-11-01 11:03:00+00:00
# 664 2019-11-01 11:04:00+00:00
# 665 2019-11-01 11:05:00+00:00
# 666 2019-11-01 11:06:00+00:00
# 667 2019-11-01 11:07:00+00:00
# 668 2019-11-01 11:08:00+00:00
# 669 2019-11-01 11:09:00+00:00
# 670 2019-11-01 11:10:00+00:00
# 671 2019-11-01 11:11:00+00:00
# 672 2019-11-01 11:12:00+00:00
# 673 2019-11-01 11:13:00+00:00
# 674 2019-11-01 11:14:00+00:00
# 675 2019-11-01 11:15:00+00:00
# 676 2019-11-01 11:16:00+00:00
# 677 2019-11-01 11:17:00+00:00
# 678 2019-11-01 11:18:00+00:00
# 679 2019-11-01 11:19:00+00:00
# 680 2019-11-01 11:20:00+00:00
# 681 2019-11-01 11:21:00+00:00
# 682 2019-11-01 11:22:00+00:00
# 683 2019-11-01 11:23:00+00:00
# 684 2019-11-01 11:24:00+00:00
# 685 2019-11-01 11:25:00+00:00
# 686 2019-11-01 11:26:00+00:00
# 687 2019-11-01 11:27:00+00:00
# 688 2019-11-01 11:28:00+00:00
# 689 2019-11-01 11:29:00+00:00
# 690 2019-11-01 11:30:00+00:00
# 691 2019-11-01 11:31:00+00:00
# 692 2019-11-01 11:32:00+00:00
# 693 2019-11-01 11:33:00+00:00
# 694 2019-11-01 11:34:00+00:00
# 695 2019-11-01 11:35:00+00:00
# 696 2019-11-01 11:36:00+00:00
# 697 2019-11-01 11:37:00+00:00
# 698 2019-11-01 11:38:00+00:00
# 699 2019-11-01 11:39:00+00:00
# 700 2019-11-01 11:40:00+00:00
# 701 2019-11-01 11:41:00+00:00
# 702 2019-11-01 11:42:00+00:00
# 703 2019-11-01 11:43:00+00:00
# 704 2019-11-01 11:44:00+00:00
# 705 2019-11-01 11:45:00+00:00
# 706 2019-11-01 11:46:00+00:00
# 707 2019-11-01 11:47:00+00:00
# 708 2019-11-01 11:48:00+00:00
# 709 2019-11-01 11:49:00+00:00
# 710 2019-11-01 11:50:00+00:00
# 711 2019-11-01 11:51:00+00:00
# 712 2019-11-01 11:52:00+00:00
# 713 2019-11-01 11:53:00+00:00
# 714 2019-11-01 11:54:00+00:00
# 715 2019-11-01 11:55:00+00:00
# 716 2019-11-01 11:56:00+00:00
# 717 2019-11-01 11:57:00+00:00
# 718 2019-11-01 11:58:00+00:00
# 719 2019-11-01 11:59:00+00:00
# 720 2019-11-01 12:00:00+00:00
# 721 2019-11-01 12:01:00+00:00
# 722 2019-11-01 12:02:00+00:00
# 723 2019-11-01 12:03:00+00:00
# 724 2019-11-01 12:04:00+00:00
# 725 2019-11-01 12:05:00+00:00
# 726 2019-11-01 12:06:00+00:00
# 727 2019-11-01 12:07:00+00:00
# 728 2019-11-01 12:08:00+00:00
# 729 2019-11-01 12:09:00+00:00
# 730 2019-11-01 12:10:00+00:00
# 731 2019-11-01 12:11:00+00:00
# 732 2019-11-01 12:12:00+00:00
# 733 2019-11-01 12:13:00+00:00
# 734 2019-11-01 12:14:00+00:00
# 735 2019-11-01 12:15:00+00:00
# 736 2019-11-01 12:16:00+00:00
# 737 2019-11-01 12:17:00+00:00
