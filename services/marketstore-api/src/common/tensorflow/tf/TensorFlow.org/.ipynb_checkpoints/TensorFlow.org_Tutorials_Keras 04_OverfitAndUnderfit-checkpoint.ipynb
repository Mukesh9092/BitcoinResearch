# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.12.0

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

# %%
def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 2s - loss: 0.5102 - acc: 0.7980 - binary_crossentropy: 0.5102 - val_loss: 0.3563 - val_acc: 0.8674 - val_binary_crossentropy: 0.3563
# Epoch 2/20
#  - 2s - loss: 0.2623 - acc: 0.9059 - binary_crossentropy: 0.2623 - val_loss: 0.2851 - val_acc: 0.8872 - val_binary_crossentropy: 0.2851
# Epoch 3/20
#  - 2s - loss: 0.1898 - acc: 0.9328 - binary_crossentropy: 0.1898 - val_loss: 0.2859 - val_acc: 0.8854 - val_binary_crossentropy: 0.2859
# Epoch 4/20
#  - 2s - loss: 0.1509 - acc: 0.9484 - binary_crossentropy: 0.1509 - val_loss: 0.3075 - val_acc: 0.8799 - val_binary_crossentropy: 0.3075
# Epoch 5/20
#  - 2s - loss: 0.1238 - acc: 0.9591 - binary_crossentropy: 0.1238 - val_loss: 0.3335 - val_acc: 0.8751 - val_binary_crossentropy: 0.3335
# Epoch 6/20
#  - 2s - loss: 0.1014 - acc: 0.9685 - binary_crossentropy: 0.1014 - val_loss: 0.3610 - val_acc: 0.8706 - val_binary_crossentropy: 0.3610
# Epoch 7/20
#  - 2s - loss: 0.0831 - acc: 0.9754 - binary_crossentropy: 0.0831 - val_loss: 0.4121 - val_acc: 0.8647 - val_binary_crossentropy: 0.4121
# Epoch 8/20
#  - 2s - loss: 0.0682 - acc: 0.9816 - binary_crossentropy: 0.0682 - val_loss: 0.4352 - val_acc: 0.8647 - val_binary_crossentropy: 0.4352
# Epoch 9/20
#  - 2s - loss: 0.0543 - acc: 0.9870 - binary_crossentropy: 0.0543 - val_loss: 0.4754 - val_acc: 0.8627 - val_binary_crossentropy: 0.4754
# Epoch 10/20
#  - 2s - loss: 0.0427 - acc: 0.9914 - binary_crossentropy: 0.0427 - val_loss: 0.5208 - val_acc: 0.8586 - val_binary_crossentropy: 0.5208
# Epoch 11/20
#  - 2s - loss: 0.0337 - acc: 0.9941 - binary_crossentropy: 0.0337 - val_loss: 0.5592 - val_acc: 0.8582 - val_binary_crossentropy: 0.5592
# Epoch 12/20
#  - 2s - loss: 0.0266 - acc: 0.9961 - binary_crossentropy: 0.0266 - val_loss: 0.6016 - val_acc: 0.8580 - val_binary_crossentropy: 0.6016
# Epoch 13/20
#  - 2s - loss: 0.0205 - acc: 0.9972 - binary_crossentropy: 0.0205 - val_loss: 0.6378 - val_acc: 0.8552 - val_binary_crossentropy: 0.6378
# Epoch 14/20
#  - 2s - loss: 0.0158 - acc: 0.9985 - binary_crossentropy: 0.0158 - val_loss: 0.6766 - val_acc: 0.8538 - val_binary_crossentropy: 0.6766
# Epoch 15/20
#  - 2s - loss: 0.0119 - acc: 0.9992 - binary_crossentropy: 0.0119 - val_loss: 0.7218 - val_acc: 0.8526 - val_binary_crossentropy: 0.7218
# Epoch 16/20
#  - 2s - loss: 0.0088 - acc: 0.9996 - binary_crossentropy: 0.0088 - val_loss: 0.7677 - val_acc: 0.8514 - val_binary_crossentropy: 0.7677
# Epoch 17/20
#  - 2s - loss: 0.0064 - acc: 0.9999 - binary_crossentropy: 0.0064 - val_loss: 0.8100 - val_acc: 0.8513 - val_binary_crossentropy: 0.8100
# Epoch 18/20
#  - 2s - loss: 0.0049 - acc: 0.9999 - binary_crossentropy: 0.0049 - val_loss: 0.8524 - val_acc: 0.8502 - val_binary_crossentropy: 0.8524
# Epoch 19/20
#  - 2s - loss: 0.0038 - acc: 1.0000 - binary_crossentropy: 0.0038 - val_loss: 0.8806 - val_acc: 0.8506 - val_binary_crossentropy: 0.8806
# Epoch 20/20
#  - 2s - loss: 0.0030 - acc: 1.0000 - binary_crossentropy: 0.0030 - val_loss: 0.9153 - val_acc: 0.8500 - val_binary_crossentropy: 0.9153

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 2s - loss: 0.5727 - acc: 0.7496 - binary_crossentropy: 0.5727 - val_loss: 0.4340 - val_acc: 0.8596 - val_binary_crossentropy: 0.4340
# Epoch 2/20
#  - 2s - loss: 0.3386 - acc: 0.8930 - binary_crossentropy: 0.3386 - val_loss: 0.3299 - val_acc: 0.8809 - val_binary_crossentropy: 0.3299
# Epoch 3/20
#  - 2s - loss: 0.2525 - acc: 0.9175 - binary_crossentropy: 0.2525 - val_loss: 0.2947 - val_acc: 0.8880 - val_binary_crossentropy: 0.2947
# Epoch 4/20
#  - 2s - loss: 0.2075 - acc: 0.9331 - binary_crossentropy: 0.2075 - val_loss: 0.2854 - val_acc: 0.8877 - val_binary_crossentropy: 0.2854
# Epoch 5/20
#  - 2s - loss: 0.1784 - acc: 0.9426 - binary_crossentropy: 0.1784 - val_loss: 0.2874 - val_acc: 0.8856 - val_binary_crossentropy: 0.2874
# Epoch 6/20
#  - 2s - loss: 0.1565 - acc: 0.9489 - binary_crossentropy: 0.1565 - val_loss: 0.2907 - val_acc: 0.8850 - val_binary_crossentropy: 0.2907
# Epoch 7/20
#  - 2s - loss: 0.1389 - acc: 0.9566 - binary_crossentropy: 0.1389 - val_loss: 0.3005 - val_acc: 0.8821 - val_binary_crossentropy: 0.3005
# Epoch 8/20
#  - 2s - loss: 0.1248 - acc: 0.9626 - binary_crossentropy: 0.1248 - val_loss: 0.3130 - val_acc: 0.8789 - val_binary_crossentropy: 0.3130
# Epoch 9/20
#  - 2s - loss: 0.1133 - acc: 0.9652 - binary_crossentropy: 0.1133 - val_loss: 0.3267 - val_acc: 0.8766 - val_binary_crossentropy: 0.3267
# Epoch 10/20
#  - 2s - loss: 0.1021 - acc: 0.9702 - binary_crossentropy: 0.1021 - val_loss: 0.3413 - val_acc: 0.8738 - val_binary_crossentropy: 0.3413
# Epoch 11/20
#  - 2s - loss: 0.0929 - acc: 0.9741 - binary_crossentropy: 0.0929 - val_loss: 0.3588 - val_acc: 0.8718 - val_binary_crossentropy: 0.3588
# Epoch 12/20
#  - 2s - loss: 0.0840 - acc: 0.9776 - binary_crossentropy: 0.0840 - val_loss: 0.3764 - val_acc: 0.8690 - val_binary_crossentropy: 0.3764
# Epoch 13/20
#  - 2s - loss: 0.0761 - acc: 0.9812 - binary_crossentropy: 0.0761 - val_loss: 0.3945 - val_acc: 0.8671 - val_binary_crossentropy: 0.3945
# Epoch 14/20
#  - 2s - loss: 0.0694 - acc: 0.9841 - binary_crossentropy: 0.0694 - val_loss: 0.4140 - val_acc: 0.8657 - val_binary_crossentropy: 0.4140
# Epoch 15/20
#  - 2s - loss: 0.0629 - acc: 0.9863 - binary_crossentropy: 0.0629 - val_loss: 0.4333 - val_acc: 0.8656 - val_binary_crossentropy: 0.4333
# Epoch 16/20
#  - 2s - loss: 0.0573 - acc: 0.9884 - binary_crossentropy: 0.0573 - val_loss: 0.4537 - val_acc: 0.8628 - val_binary_crossentropy: 0.4537
# Epoch 17/20
#  - 1s - loss: 0.0523 - acc: 0.9900 - binary_crossentropy: 0.0523 - val_loss: 0.4751 - val_acc: 0.8618 - val_binary_crossentropy: 0.4751
# Epoch 18/20
#  - 2s - loss: 0.0470 - acc: 0.9918 - binary_crossentropy: 0.0470 - val_loss: 0.4985 - val_acc: 0.8592 - val_binary_crossentropy: 0.4985
# Epoch 19/20
#  - 2s - loss: 0.0425 - acc: 0.9934 - binary_crossentropy: 0.0425 - val_loss: 0.5173 - val_acc: 0.8586 - val_binary_crossentropy: 0.5173
# Epoch 20/20
#  - 2s - loss: 0.0385 - acc: 0.9942 - binary_crossentropy: 0.0385 - val_loss: 0.5397 - val_acc: 0.8576 - val_binary_crossentropy: 0.5397

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 10s - loss: 0.3489 - acc: 0.8546 - binary_crossentropy: 0.3489 - val_loss: 0.3069 - val_acc: 0.8751 - val_binary_crossentropy: 0.3069
# Epoch 2/20
#  - 9s - loss: 0.1384 - acc: 0.9495 - binary_crossentropy: 0.1384 - val_loss: 0.3650 - val_acc: 0.8613 - val_binary_crossentropy: 0.3650
# Epoch 3/20
#  - 10s - loss: 0.0449 - acc: 0.9869 - binary_crossentropy: 0.0449 - val_loss: 0.4252 - val_acc: 0.8674 - val_binary_crossentropy: 0.4252
# Epoch 4/20
#  - 10s - loss: 0.0073 - acc: 0.9990 - binary_crossentropy: 0.0073 - val_loss: 0.5770 - val_acc: 0.8686 - val_binary_crossentropy: 0.5770
# Epoch 5/20
#  - 10s - loss: 8.8422e-04 - acc: 1.0000 - binary_crossentropy: 8.8422e-04 - val_loss: 0.6629 - val_acc: 0.8708 - val_binary_crossentropy: 0.6629
# Epoch 6/20
#  - 10s - loss: 2.3126e-04 - acc: 1.0000 - binary_crossentropy: 2.3126e-04 - val_loss: 0.7045 - val_acc: 0.8706 - val_binary_crossentropy: 0.7045
# Epoch 7/20
#  - 10s - loss: 1.4213e-04 - acc: 1.0000 - binary_crossentropy: 1.4213e-04 - val_loss: 0.7302 - val_acc: 0.8710 - val_binary_crossentropy: 0.7302
# Epoch 8/20
#  - 10s - loss: 1.0205e-04 - acc: 1.0000 - binary_crossentropy: 1.0205e-04 - val_loss: 0.7493 - val_acc: 0.8712 - val_binary_crossentropy: 0.7493
# Epoch 9/20
#  - 10s - loss: 7.7815e-05 - acc: 1.0000 - binary_crossentropy: 7.7815e-05 - val_loss: 0.7656 - val_acc: 0.8707 - val_binary_crossentropy: 0.7656
# Epoch 10/20
#  - 10s - loss: 6.1546e-05 - acc: 1.0000 - binary_crossentropy: 6.1546e-05 - val_loss: 0.7788 - val_acc: 0.8709 - val_binary_crossentropy: 0.7788
# Epoch 11/20
#  - 10s - loss: 4.9933e-05 - acc: 1.0000 - binary_crossentropy: 4.9933e-05 - val_loss: 0.7914 - val_acc: 0.8705 - val_binary_crossentropy: 0.7914
# Epoch 12/20
#  - 10s - loss: 4.1234e-05 - acc: 1.0000 - binary_crossentropy: 4.1234e-05 - val_loss: 0.8023 - val_acc: 0.8709 - val_binary_crossentropy: 0.8023
# Epoch 13/20
#  - 10s - loss: 3.4588e-05 - acc: 1.0000 - binary_crossentropy: 3.4588e-05 - val_loss: 0.8120 - val_acc: 0.8711 - val_binary_crossentropy: 0.8120
# Epoch 14/20
#  - 10s - loss: 2.9393e-05 - acc: 1.0000 - binary_crossentropy: 2.9393e-05 - val_loss: 0.8214 - val_acc: 0.8711 - val_binary_crossentropy: 0.8214
# Epoch 15/20
#  - 10s - loss: 2.5200e-05 - acc: 1.0000 - binary_crossentropy: 2.5200e-05 - val_loss: 0.8301 - val_acc: 0.8712 - val_binary_crossentropy: 0.8301
# Epoch 16/20
#  - 9s - loss: 2.1827e-05 - acc: 1.0000 - binary_crossentropy: 2.1827e-05 - val_loss: 0.8373 - val_acc: 0.8715 - val_binary_crossentropy: 0.8373
# Epoch 17/20
#  - 10s - loss: 1.9037e-05 - acc: 1.0000 - binary_crossentropy: 1.9037e-05 - val_loss: 0.8458 - val_acc: 0.8710 - val_binary_crossentropy: 0.8458
# Epoch 18/20
#  - 10s - loss: 1.6743e-05 - acc: 1.0000 - binary_crossentropy: 1.6743e-05 - val_loss: 0.8521 - val_acc: 0.8715 - val_binary_crossentropy: 0.8521
# Epoch 19/20
#  - 10s - loss: 1.4772e-05 - acc: 1.0000 - binary_crossentropy: 1.4772e-05 - val_loss: 0.8591 - val_acc: 0.8714 - val_binary_crossentropy: 0.8591
# Epoch 20/20
#  - 10s - loss: 1.3125e-05 - acc: 1.0000 - binary_crossentropy: 1.3125e-05 - val_loss: 0.8660 - val_acc: 0.8712 - val_binary_crossentropy: 0.8660

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5065 - acc: 0.8129 - binary_crossentropy: 0.4619 - val_loss: 0.3701 - val_acc: 0.8805 - val_binary_crossentropy: 0.3231
# Epoch 2/20
#  - 2s - loss: 0.2975 - acc: 0.9120 - binary_crossentropy: 0.2470 - val_loss: 0.3368 - val_acc: 0.8877 - val_binary_crossentropy: 0.2838
# Epoch 3/20
#  - 3s - loss: 0.2506 - acc: 0.9318 - binary_crossentropy: 0.1955 - val_loss: 0.3424 - val_acc: 0.8844 - val_binary_crossentropy: 0.2857
# Epoch 4/20
#  - 2s - loss: 0.2260 - acc: 0.9423 - binary_crossentropy: 0.1678 - val_loss: 0.3578 - val_acc: 0.8807 - val_binary_crossentropy: 0.2987
# Epoch 5/20
#  - 3s - loss: 0.2135 - acc: 0.9482 - binary_crossentropy: 0.1528 - val_loss: 0.3706 - val_acc: 0.8788 - val_binary_crossentropy: 0.3089
# Epoch 6/20
#  - 2s - loss: 0.2003 - acc: 0.9530 - binary_crossentropy: 0.1381 - val_loss: 0.3893 - val_acc: 0.8738 - val_binary_crossentropy: 0.3267
# Epoch 7/20
#  - 3s - loss: 0.1935 - acc: 0.9560 - binary_crossentropy: 0.1298 - val_loss: 0.4034 - val_acc: 0.8719 - val_binary_crossentropy: 0.3389
# Epoch 8/20
#  - 2s - loss: 0.1857 - acc: 0.9604 - binary_crossentropy: 0.1205 - val_loss: 0.4169 - val_acc: 0.8703 - val_binary_crossentropy: 0.3515
# Epoch 9/20
#  - 2s - loss: 0.1803 - acc: 0.9609 - binary_crossentropy: 0.1144 - val_loss: 0.4355 - val_acc: 0.8684 - val_binary_crossentropy: 0.3689
# Epoch 10/20
#  - 2s - loss: 0.1784 - acc: 0.9623 - binary_crossentropy: 0.1112 - val_loss: 0.4508 - val_acc: 0.8642 - val_binary_crossentropy: 0.3832
# Epoch 11/20
#  - 3s - loss: 0.1737 - acc: 0.9644 - binary_crossentropy: 0.1056 - val_loss: 0.4634 - val_acc: 0.8641 - val_binary_crossentropy: 0.3947
# Epoch 12/20
#  - 2s - loss: 0.1708 - acc: 0.9652 - binary_crossentropy: 0.1020 - val_loss: 0.4862 - val_acc: 0.8598 - val_binary_crossentropy: 0.4170
# Epoch 13/20
#  - 3s - loss: 0.1695 - acc: 0.9657 - binary_crossentropy: 0.0995 - val_loss: 0.4896 - val_acc: 0.8606 - val_binary_crossentropy: 0.4193
# Epoch 14/20
#  - 2s - loss: 0.1616 - acc: 0.9685 - binary_crossentropy: 0.0914 - val_loss: 0.4980 - val_acc: 0.8584 - val_binary_crossentropy: 0.4281
# Epoch 15/20
#  - 3s - loss: 0.1558 - acc: 0.9722 - binary_crossentropy: 0.0861 - val_loss: 0.5134 - val_acc: 0.8582 - val_binary_crossentropy: 0.4435
# Epoch 16/20
#  - 2s - loss: 0.1546 - acc: 0.9726 - binary_crossentropy: 0.0844 - val_loss: 0.5269 - val_acc: 0.8558 - val_binary_crossentropy: 0.4565
# Epoch 17/20
#  - 3s - loss: 0.1531 - acc: 0.9722 - binary_crossentropy: 0.0827 - val_loss: 0.5392 - val_acc: 0.8550 - val_binary_crossentropy: 0.4683
# Epoch 18/20
#  - 2s - loss: 0.1530 - acc: 0.9713 - binary_crossentropy: 0.0819 - val_loss: 0.5582 - val_acc: 0.8538 - val_binary_crossentropy: 0.4866
# Epoch 19/20
#  - 3s - loss: 0.1515 - acc: 0.9730 - binary_crossentropy: 0.0797 - val_loss: 0.5567 - val_acc: 0.8574 - val_binary_crossentropy: 0.4847
# Epoch 20/20
#  - 2s - loss: 0.1498 - acc: 0.9732 - binary_crossentropy: 0.0776 - val_loss: 0.5712 - val_acc: 0.8530 - val_binary_crossentropy: 0.4988

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.6312 - acc: 0.6364 - binary_crossentropy: 0.6312 - val_loss: 0.5023 - val_acc: 0.8429 - val_binary_crossentropy: 0.5023
# Epoch 2/20
#  - 2s - loss: 0.4720 - acc: 0.7940 - binary_crossentropy: 0.4720 - val_loss: 0.3541 - val_acc: 0.8803 - val_binary_crossentropy: 0.3541
# Epoch 3/20
#  - 3s - loss: 0.3712 - acc: 0.8568 - binary_crossentropy: 0.3712 - val_loss: 0.2966 - val_acc: 0.8870 - val_binary_crossentropy: 0.2966
# Epoch 4/20
#  - 2s - loss: 0.3061 - acc: 0.8952 - binary_crossentropy: 0.3061 - val_loss: 0.2792 - val_acc: 0.8886 - val_binary_crossentropy: 0.2792
# Epoch 5/20
#  - 3s - loss: 0.2576 - acc: 0.9149 - binary_crossentropy: 0.2576 - val_loss: 0.2809 - val_acc: 0.8873 - val_binary_crossentropy: 0.2809
# Epoch 6/20
#  - 2s - loss: 0.2197 - acc: 0.9264 - binary_crossentropy: 0.2197 - val_loss: 0.2924 - val_acc: 0.8860 - val_binary_crossentropy: 0.2924
# Epoch 7/20
#  - 3s - loss: 0.1938 - acc: 0.9346 - binary_crossentropy: 0.1938 - val_loss: 0.3164 - val_acc: 0.8796 - val_binary_crossentropy: 0.3164
# Epoch 8/20
#  - 2s - loss: 0.1715 - acc: 0.9449 - binary_crossentropy: 0.1715 - val_loss: 0.3213 - val_acc: 0.8820 - val_binary_crossentropy: 0.3213
# Epoch 9/20
#  - 3s - loss: 0.1600 - acc: 0.9456 - binary_crossentropy: 0.1600 - val_loss: 0.3428 - val_acc: 0.8803 - val_binary_crossentropy: 0.3428
# Epoch 10/20
#  - 2s - loss: 0.1415 - acc: 0.9518 - binary_crossentropy: 0.1415 - val_loss: 0.3552 - val_acc: 0.8797 - val_binary_crossentropy: 0.3552
# Epoch 11/20
#  - 2s - loss: 0.1266 - acc: 0.9576 - binary_crossentropy: 0.1266 - val_loss: 0.3859 - val_acc: 0.8799 - val_binary_crossentropy: 0.3859
# Epoch 12/20
#  - 2s - loss: 0.1199 - acc: 0.9596 - binary_crossentropy: 0.1199 - val_loss: 0.4040 - val_acc: 0.8797 - val_binary_crossentropy: 0.4040
# Epoch 13/20
#  - 3s - loss: 0.1099 - acc: 0.9637 - binary_crossentropy: 0.1099 - val_loss: 0.4153 - val_acc: 0.8763 - val_binary_crossentropy: 0.4153
# Epoch 14/20
#  - 2s - loss: 0.1046 - acc: 0.9648 - binary_crossentropy: 0.1046 - val_loss: 0.4314 - val_acc: 0.8760 - val_binary_crossentropy: 0.4314
# Epoch 15/20
#  - 3s - loss: 0.0972 - acc: 0.9673 - binary_crossentropy: 0.0972 - val_loss: 0.4530 - val_acc: 0.8745 - val_binary_crossentropy: 0.4530
# Epoch 16/20
#  - 2s - loss: 0.0927 - acc: 0.9685 - binary_crossentropy: 0.0927 - val_loss: 0.4821 - val_acc: 0.8761 - val_binary_crossentropy: 0.4821
# Epoch 17/20
#  - 3s - loss: 0.0862 - acc: 0.9697 - binary_crossentropy: 0.0862 - val_loss: 0.4966 - val_acc: 0.8758 - val_binary_crossentropy: 0.4966
# Epoch 18/20
#  - 2s - loss: 0.0806 - acc: 0.9729 - binary_crossentropy: 0.0806 - val_loss: 0.5250 - val_acc: 0.8767 - val_binary_crossentropy: 0.5250
# Epoch 19/20
#  - 3s - loss: 0.0765 - acc: 0.9743 - binary_crossentropy: 0.0765 - val_loss: 0.5407 - val_acc: 0.8757 - val_binary_crossentropy: 0.5407
# Epoch 20/20
#  - 2s - loss: 0.0764 - acc: 0.9733 - binary_crossentropy: 0.0764 - val_loss: 0.5145 - val_acc: 0.8715 - val_binary_crossentropy: 0.5145

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history),
              ('dropout', dpt_model_history)])
