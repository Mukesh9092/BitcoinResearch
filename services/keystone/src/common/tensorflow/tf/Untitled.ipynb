# %%
# !echo $(python --version)
# !echo $(pip --version)
# Out:
# Python 3.6.9
# pip 19.3.1 from /usr/local/lib/python3.6/dist-packages/pip (python 3.6)

# %%
# %matplotlib inline

# %%
# !catalyst ingest-exchange -x binance -f daily
#!catalyst ingest-exchange -x binance -f minute
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting daily price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i ada_usdt
# !catalyst ingest-exchange -x binance -f minute -i algo_usdt
# !catalyst ingest-exchange -x binance -f minute -i ankr_usdt
#!catalyst ingest-exchange -x binance -f minute -i atom_usdt
# !catalyst ingest-exchange -x binance -f minute -i band_usdt
# !catalyst ingest-exchange -x binance -f minute -i bat_usdt
# !catalyst ingest-exchange -x binance -f minute -i beam_usdt
# !catalyst ingest-exchange -x binance -f minute -i bnb_usdt
# !catalyst ingest-exchange -x binance -f minute -i btc_usdt
# !catalyst ingest-exchange -x binance -f minute -i btt_usdt
# Out:
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i busd_usdt
# !catalyst ingest-exchange -x binance -f minute -i celr_usdt
# !catalyst ingest-exchange -x binance -f minute -i chz_usdt
# !catalyst ingest-exchange -x binance -f minute -i cocos_usdt
# !catalyst ingest-exchange -x binance -f minute -i cos_usdt
# !catalyst ingest-exchange -x binance -f minute -i cvc_usdt
# !catalyst ingest-exchange -x binance -f minute -i dash_usdt
# !catalyst ingest-exchange -x binance -f minute -i dent_usdt
# !catalyst ingest-exchange -x binance -f minute -i dock_usdt
# !catalyst ingest-exchange -x binance -f minute -i doge_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i dusk_usdt
# !catalyst ingest-exchange -x binance -f minute -i enj_usdt
# !catalyst ingest-exchange -x binance -f minute -i eos_usdt
# !catalyst ingest-exchange -x binance -f minute -i erd_usdt
# !catalyst ingest-exchange -x binance -f minute -i etc_usdt
# !catalyst ingest-exchange -x binance -f minute -i eth_usdt
# !catalyst ingest-exchange -x binance -f minute -i fet_usdt
# !catalyst ingest-exchange -x binance -f minute -i ftm_usdt
# !catalyst ingest-exchange -x binance -f minute -i fun_usdt
# !catalyst ingest-exchange -x binance -f minute -i gto_usdt
#!catalyst ingest-exchange -x binance -f minute -i hbar_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i hc_usdt
# !catalyst ingest-exchange -x binance -f minute -i hot_usdt
# !catalyst ingest-exchange -x binance -f minute -i icx_usdt
# !catalyst ingest-exchange -x binance -f minute -i iost_usdt
# !catalyst ingest-exchange -x binance -f minute -i iota_usdt
# !catalyst ingest-exchange -x binance -f minute -i kava_usdt
# !catalyst ingest-exchange -x binance -f minute -i key_usdt
# !catalyst ingest-exchange -x binance -f minute -i link_usdt
# !catalyst ingest-exchange -x binance -f minute -i ltc_usdt
# !catalyst ingest-exchange -x binance -f minute -i matic_usdt
# !catalyst ingest-exchange -x binance -f minute -i mft_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%

# %%
# !catalyst ingest-exchange -x binance -f minute -i mith_usdt
# !catalyst ingest-exchange -x binance -f minute -i mtl_usdt
# !catalyst ingest-exchange -x binance -f minute -i nano_usdt
# !catalyst ingest-exchange -x binance -f minute -i neo_usdt
# !catalyst ingest-exchange -x binance -f minute -i nkn_usdt
# !catalyst ingest-exchange -x binance -f minute -i npxs_usdt
# !catalyst ingest-exchange -x binance -f minute -i nuls_usdt
# !catalyst ingest-exchange -x binance -f minute -i omg_usdt
# !catalyst ingest-exchange -x binance -f minute -i one_usdt
# !catalyst ingest-exchange -x binance -f minute -i ong_usdt
# !catalyst ingest-exchange -x binance -f minute -i ont_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i pax_usdt
# !catalyst ingest-exchange -x binance -f minute -i perl_usdt
# !catalyst ingest-exchange -x binance -f minute -i qtum_usdt
# !catalyst ingest-exchange -x binance -f minute -i ren_usdt
# !catalyst ingest-exchange -x binance -f minute -i rvn_usdt
# !catalyst ingest-exchange -x binance -f minute -i storm_usdt
# !catalyst ingest-exchange -x binance -f minute -i stx_usdt
# !catalyst ingest-exchange -x binance -f minute -i tfuel_usdt
# !catalyst ingest-exchange -x binance -f minute -i theta_usdt
# !catalyst ingest-exchange -x binance -f minute -i tomo_usdt
# !catalyst ingest-exchange -x binance -f minute -i trx_usdt
# Out:
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
# !catalyst ingest-exchange -x binance -f minute -i tusd_usdt
# !catalyst ingest-exchange -x binance -f minute -i usdc_usdt
# !catalyst ingest-exchange -x binance -f minute -i usds_usdt
# !catalyst ingest-exchange -x binance -f minute -i vet_usdt
# !catalyst ingest-exchange -x binance -f minute -i wan_usdt
# !catalyst ingest-exchange -x binance -f minute -i waves_usdt
# !catalyst ingest-exchange -x binance -f minute -i win_usdt
# !catalyst ingest-exchange -x binance -f minute -i xlm_usdt
# !catalyst ingest-exchange -x binance -f minute -i xmr_usdt
# !catalyst ingest-exchange -x binance -f minute -i xrp_usdt
# !catalyst ingest-exchange -x binance -f minute -i xtz_usdt
# !catalyst ingest-exchange -x binance -f minute -i zec_usdt
# !catalyst ingest-exchange -x binance -f minute -i zil_usdt
# !catalyst ingest-exchange -x binance -f minute -i zrx_usdt
# Out:
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...
#     [====================================]  Ingesting minute price data on binance:  100%
# Trying to ingest exchange bundle binance...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# import pyfolio as pf

from catalyst.utils.run_algo import run_algorithm
from catalyst.api import order_target_percent, record, symbol
from catalyst.exchange.utils.exchange_utils import get_exchange_symbols

# %%
BASE_CAPITAL = 1000
BASE_CURRENCY = 'usdt'
EXCHANGE_NAME = 'binance'
START_DATE = '2019-01-01'
END_DATE = '2019-12-01'
FREQUENCY = '1D' # 1T (minutes), 1H (hours) or 1D (days).
API_FREQUENCY = FREQUENCY == '1D' and 'daily' or 'minute'
SHORT_EMA_LENGTH = 5
LONG_EMA_LENGTH = 20
DISABLED_MARKETS = [
    'atom_usdt',
    'hbar_usdt'
]

# %%
# TODO: Document properly.
def datetime_date(datetime):
    return datetime.strftime('%Y-%m-%d')

# %%
def get_market_label(market_key):
    """Get a label from a market key.

    Parameters
    ----------
    market_key : str
        The market key to format.

    Returns
    -------
    market_label : str
        The market_key formatted as a label.
    """

    return market_key.upper().split('_')[0]

# %%
def frequency_in_minutes(frequency):
    """Get the frequency as an amount of minutes.

    Parameters
    ----------
    frequency : str
        1T (minutes), 1H (hours) or 1D (days).

    Returns
    -------
    frequency_minutes : int
        The frequency expressed as an amount of minutes.
    """

    if frequency == '1T':
        return 1
    elif frequency == '1H':
        return 60
    elif frequency == '1D':
        return 60 * 24

# %%
def initialize(context):
    """Initializes the backtest.

    Parameters
    ----------
    context : catalyst.ExchangeTradingAlgorithmBacktest
        The backtest object. This is used as shared state and to collect results.
    """

    context.i = -1
    context.exchange = 'binance'
    context.quote_currency = BASE_CURRENCY
    context.frequency = FREQUENCY
    context.loop_interval = FREQUENCY == '1D' and 1 or frequency_in_minutes(FREQUENCY)
    context.short_sma_length = SHORT_EMA_LENGTH
    context.short_sma_frequency = FREQUENCY
    context.long_sma_length = LONG_EMA_LENGTH
    context.long_sma_frequency = FREQUENCY
    context.universe = universe(
        context,
        datetime_date(context.sim_params.start_session),
        datetime_date(context.sim_params.end_session)
    )

    print('Universe Size: %s' % (len(context.universe)))

# %%
# TODO: Document properly.
def universe(context, start_date, end_date):
    """Returns a list of symbols to trade."""
    
    # get all the pairs for the given exchange
    json_symbols = get_exchange_symbols(context.exchange)

    # convert into a DataFrame for easier processing
    df = pd.DataFrame.from_dict(json_symbols).transpose().astype(str)
    df['quote_currency'] = df.apply(
        lambda row: row.symbol.split('_')[1],
        axis=1
    )
    df['base_currency'] = df.apply(
        lambda row: row.symbol.split('_')[0],
        axis=1
    )
    
    # print('universe df all pairs %s %s' % (len(df), df.symbol.tolist()))

    # Filter all the pairs to get only the ones for a given quote_currency
    df = df[df['quote_currency'] == context.quote_currency]
    
    # print('universe df quote pairs %s %s' % (len(df), df.symbol.tolist()))
    # print('universe df too late pairs %s %s' % (len(df[df.start_date < start_date]), df[df.start_date < start_date].symbol.tolist()))
    # print('universe df too early pairs %s %s' % (len(df[df.end_daily > end_date]), df[df.end_daily > end_date].symbol.tolist()))

    # Filter all pairs to ensure that pair existed in the current date range
    df = df[df.start_date < start_date]
    df = df[df.end_daily > end_date]

    # print('universe df after dates end: %s' % (len(df)))
    
    filtered_universe = [x for x in df.symbol.tolist() if x not in DISABLED_MARKETS]

    # print('universe df after filter: %s' % (len(df)))
    
    for x in filtered_universe:
        print(x)

    return filtered_universe

# %%
# TODO: Document properly.
def analyze(context, results):
    """Analyzes the results when the backtest is done."""

    fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(8, 12))

    results[['cash']].plot(ax=ax1)
    ax1.set_xlabel('')
    ax1.set_ylabel('')
    ax1.legend(['Cash (BTC)'])

    results[['returns']].plot(ax=ax2)
    ax2.set_xlabel('')
    ax2.set_ylabel('')
    ax2.legend(['Returns (BTC)'])

    # plt.subplots_adjust(hspace=2.0)
    plt.tight_layout()
    plt.show()

# %%
def recalculate(context, bar_data):
    """Returns the values for the algorithm for each Asset for this Bar.

    Parameters
    ----------
    context : di
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    context.values = {}

    for market_key in context.universe:
        market_symbol = symbol(market_key)

        # Get the current price.
        price_value = bar_data.current(market_symbol, 'price')

        # Calculate the Short SMA.
        short_sma_data = bar_data.history(
            market_symbol,
            'price',
            bar_count=context.short_sma_length,
            frequency=context.short_sma_frequency,
        )
        short_sma_value = short_sma_data.mean()

        # Calculate the Long SMA.
        long_sma_data = bar_data.history(
            market_symbol,
            'price',
            bar_count=context.long_sma_length,
            frequency=context.long_sma_frequency,
        )
        long_sma_value = long_sma_data.mean()

        # Save data per market in the context.
        context.values[market_key] = {
            'price': price_value,
            'short_sma': short_sma_value,
            'long_sma': long_sma_value,
        }

# %%
def rebalance(context, bar_data):
    """Opens Buy and Sell orders and closes orders for this Bar.

    Parameters
    ----------
    context : catalyst.exchange.exchange_algorithm.ExchangeTradingAlgorithmBacktest
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    # Wait until all orders are executed before considering more trades.
    orders = context.blotter.open_orders
    if len(orders) > 0:
        return

    total_symbols = 0
    open_market_symbols = []
    close_market_symbols = []

    for market_key in context.universe:
        market_symbol = symbol(market_key)

        # Exit if we cannot trade.
        if not bar_data.can_trade(market_symbol):
            return

        # We check what's our position on our portfolio and trade accordingly.
        market = context.values[market_key]

        if market['short_sma'] > market['long_sma']:
            open_market_symbols.append(market_symbol)
        elif market['short_sma'] < market['long_sma']:
            close_market_symbols.append(market_symbol)
        
        total_symbols = total_symbols + 1

    for market_symbol in close_market_symbols:
        if context.portfolio.positions[market_symbol].amount > 0:
            order_target_percent(market_symbol, 0)
    
    for market_symbol in open_market_symbols:
        order_target_percent(market_symbol, 1 / total_symbols)

    print("Total: %s, Open: %s, Close: %s" % (total_symbols, len(open_market_symbols), len(close_market_symbols)))

# %%
def handle_data(context, bar_data):
    """Get the frequency as an amount of minutes.

    Parameters
    ----------
    context : catalyst.exchange.exchange_algorithm.ExchangeTradingAlgorithmBacktest
        Represents the backtest state.
    bar_data : catalyst._protocol.BarData
        The data for the current period.
    """

    context.i += 1

    # We need a minimum of LONG_EMA_LENGTH bars to calculate.
    if context.i < context.long_sma_length:
        return

    if context.i % context.loop_interval != 0:
        return

    current_date = bar_data.current_dt

    print("%s %s" % (context.i, current_date))

    recalculate(context, bar_data)
    rebalance(context, bar_data)

    # Save columns for Performance.
    record(
        cash=context.portfolio.cash,
        returns=context.portfolio.returns,
    )

# %%
algorithm_results = run_algorithm(
    capital_base=BASE_CAPITAL,
    start=pd.to_datetime(START_DATE, utc=True),
    end=pd.to_datetime(END_DATE, utc=True),
    initialize=initialize,
    handle_data=handle_data,
    analyze=analyze,
    data_frequency=API_FREQUENCY,
    live=False,
    exchange_name=EXCHANGE_NAME,
    quote_currency=BASE_CURRENCY,
    algo_namespace='test',
    live_graph=False
)

#returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(algorithm_results)
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')
# Out:
# [2019-12-05 18:21:28.215216] INFO: run_algo: Catalyst version 0.5.21
# [2019-12-05 18:21:28.216149] WARNING: run_algo: Catalyst is currently in ALPHA. It is going through rapid development and it is subject to errors. Please use carefully. We encourage you to report any issue on GitHub: https://github.com/enigmampc/catalyst/issues
# [2019-12-05 18:21:31.220061] INFO: run_algo: running algo in backtest mode
# [2019-12-05 18:21:31.767207] INFO: exchange_algorithm: initialized trading algorithm in backtest mode
# ada_usdt
# algo_usdt
# ankr_usdt
# band_usdt
# bat_usdt
# beam_usdt
# bnb_usdt
# btc_usdt
# btt_usdt
# busd_usdt
# celr_usdt
# chz_usdt
# cocos_usdt
# cos_usdt
# cvc_usdt
# dash_usdt
# dent_usdt
# dock_usdt
# doge_usdt
# dusk_usdt
# enj_usdt
# eos_usdt
# erd_usdt
# etc_usdt
# eth_usdt
# fet_usdt
# ftm_usdt
# fun_usdt
# gto_usdt
# hc_usdt
# hot_usdt
# icx_usdt
# iost_usdt
# iota_usdt
# kava_usdt
# key_usdt
# link_usdt
# ltc_usdt
# matic_usdt
# mft_usdt
# mith_usdt
# mtl_usdt
# nano_usdt
# neo_usdt
# nkn_usdt
# npxs_usdt
# nuls_usdt
# omg_usdt
# one_usdt
# ong_usdt
# ont_usdt
# pax_usdt
# perl_usdt
# qtum_usdt
# ren_usdt
# rvn_usdt
# storm_usdt
# stx_usdt
# tfuel_usdt
# theta_usdt
# tomo_usdt
# trx_usdt
# tusd_usdt
# usdc_usdt
# usds_usdt
# vet_usdt
# wan_usdt
# waves_usdt
# win_usdt
# xlm_usdt
# xmr_usdt
# xrp_usdt
# xtz_usdt
# zec_usdt
# zil_usdt
# zrx_usdt
# Universe Size: 76
# 60 2019-11-01 01:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 120 2019-11-01 02:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 180 2019-11-01 03:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 240 2019-11-01 04:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 300 2019-11-01 05:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 360 2019-11-01 06:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 420 2019-11-01 07:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 480 2019-11-01 08:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 540 2019-11-01 09:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 600 2019-11-01 10:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 660 2019-11-01 11:00:00+00:00
# Total: 76, Open: 36, Close: 39
# 720 2019-11-01 12:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 780 2019-11-01 13:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 840 2019-11-01 14:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 900 2019-11-01 15:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 960 2019-11-01 16:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 1020 2019-11-01 17:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 1080 2019-11-01 18:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 1140 2019-11-01 19:00:00+00:00
# Total: 76, Open: 46, Close: 29
# 1200 2019-11-01 20:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 1260 2019-11-01 21:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 1320 2019-11-01 22:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 1380 2019-11-01 23:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 1440 2019-11-02 00:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 1500 2019-11-02 01:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 1560 2019-11-02 02:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 1620 2019-11-02 03:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 1680 2019-11-02 04:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 1740 2019-11-02 05:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 1800 2019-11-02 06:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 1860 2019-11-02 07:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 1920 2019-11-02 08:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 1980 2019-11-02 09:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 2040 2019-11-02 10:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 2100 2019-11-02 11:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 2160 2019-11-02 12:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 2220 2019-11-02 13:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 2280 2019-11-02 14:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 2340 2019-11-02 15:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 2400 2019-11-02 16:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 2460 2019-11-02 17:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 2520 2019-11-02 18:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 2580 2019-11-02 19:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 2640 2019-11-02 20:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 2700 2019-11-02 21:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 2760 2019-11-02 22:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 2820 2019-11-02 23:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 2880 2019-11-03 00:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 2940 2019-11-03 01:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 3000 2019-11-03 02:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 3060 2019-11-03 03:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 3120 2019-11-03 04:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 3180 2019-11-03 05:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 3240 2019-11-03 06:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 3300 2019-11-03 07:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 3360 2019-11-03 08:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 3420 2019-11-03 09:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 3480 2019-11-03 10:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 3540 2019-11-03 11:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 3600 2019-11-03 12:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 3660 2019-11-03 13:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 3720 2019-11-03 14:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 3780 2019-11-03 15:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 3840 2019-11-03 16:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 3900 2019-11-03 17:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 3960 2019-11-03 18:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 4020 2019-11-03 19:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 4080 2019-11-03 20:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 4140 2019-11-03 21:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 4200 2019-11-03 22:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 4260 2019-11-03 23:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 4320 2019-11-04 00:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 4380 2019-11-04 01:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 4440 2019-11-04 02:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 4500 2019-11-04 03:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 4560 2019-11-04 04:00:00+00:00
# Total: 76, Open: 46, Close: 29
# 4620 2019-11-04 05:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 4680 2019-11-04 06:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 4740 2019-11-04 07:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 4800 2019-11-04 08:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 4860 2019-11-04 09:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 4920 2019-11-04 10:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 4980 2019-11-04 11:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 5040 2019-11-04 12:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 5100 2019-11-04 13:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 5160 2019-11-04 14:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 5220 2019-11-04 15:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 5280 2019-11-04 16:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 5340 2019-11-04 17:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 5400 2019-11-04 18:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 5460 2019-11-04 19:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 5520 2019-11-04 20:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 5580 2019-11-04 21:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 5640 2019-11-04 22:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 5700 2019-11-04 23:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 5760 2019-11-05 00:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 5820 2019-11-05 01:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 5880 2019-11-05 02:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 5940 2019-11-05 03:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 6000 2019-11-05 04:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 6060 2019-11-05 05:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 6120 2019-11-05 06:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 6180 2019-11-05 07:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 6240 2019-11-05 08:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 6300 2019-11-05 09:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 6360 2019-11-05 10:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 6420 2019-11-05 11:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 6480 2019-11-05 12:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 6540 2019-11-05 13:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 6600 2019-11-05 14:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 6660 2019-11-05 15:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 6720 2019-11-05 16:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 6780 2019-11-05 17:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 6840 2019-11-05 18:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 6900 2019-11-05 19:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 6960 2019-11-05 20:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 7020 2019-11-05 21:00:00+00:00
# Total: 76, Open: 67, Close: 9
# 7080 2019-11-05 22:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 7140 2019-11-05 23:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 7200 2019-11-06 00:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 7260 2019-11-06 01:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 7320 2019-11-06 02:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 7380 2019-11-06 03:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 7440 2019-11-06 04:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 7500 2019-11-06 05:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 7560 2019-11-06 06:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 7620 2019-11-06 07:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 7680 2019-11-06 08:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 7740 2019-11-06 09:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 7800 2019-11-06 10:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 7860 2019-11-06 11:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 7920 2019-11-06 12:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 7980 2019-11-06 13:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 8040 2019-11-06 14:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 8100 2019-11-06 15:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 8160 2019-11-06 16:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 8220 2019-11-06 17:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 8280 2019-11-06 18:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 8340 2019-11-06 19:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 8400 2019-11-06 20:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 8460 2019-11-06 21:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 8520 2019-11-06 22:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 8580 2019-11-06 23:00:00+00:00
# Total: 76, Open: 32, Close: 43
# 8640 2019-11-07 00:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 8700 2019-11-07 01:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 8760 2019-11-07 02:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 8820 2019-11-07 03:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 8880 2019-11-07 04:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 8940 2019-11-07 05:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 9000 2019-11-07 06:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 9060 2019-11-07 07:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 9120 2019-11-07 08:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 9180 2019-11-07 09:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 9240 2019-11-07 10:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 9300 2019-11-07 11:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 9360 2019-11-07 12:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 9420 2019-11-07 13:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 9480 2019-11-07 14:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 9540 2019-11-07 15:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 9600 2019-11-07 16:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 9660 2019-11-07 17:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 9720 2019-11-07 18:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 9780 2019-11-07 19:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 9840 2019-11-07 20:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 9900 2019-11-07 21:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 9960 2019-11-07 22:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 10020 2019-11-07 23:00:00+00:00
# Total: 76, Open: 34, Close: 42
# 10080 2019-11-08 00:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 10140 2019-11-08 01:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 10200 2019-11-08 02:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 10260 2019-11-08 03:00:00+00:00
# Total: 76, Open: 53, Close: 22
# 10320 2019-11-08 04:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 10380 2019-11-08 05:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 10440 2019-11-08 06:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 10500 2019-11-08 07:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 10560 2019-11-08 08:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 10620 2019-11-08 09:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 10680 2019-11-08 10:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 10740 2019-11-08 11:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 10800 2019-11-08 12:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 10860 2019-11-08 13:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 10920 2019-11-08 14:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 10980 2019-11-08 15:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 11040 2019-11-08 16:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 11100 2019-11-08 17:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 11160 2019-11-08 18:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 11220 2019-11-08 19:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 11280 2019-11-08 20:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 11340 2019-11-08 21:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 11400 2019-11-08 22:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 11460 2019-11-08 23:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 11520 2019-11-09 00:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 11580 2019-11-09 01:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 11640 2019-11-09 02:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 11700 2019-11-09 03:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 11760 2019-11-09 04:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 11820 2019-11-09 05:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 11880 2019-11-09 06:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 11940 2019-11-09 07:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 12000 2019-11-09 08:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 12060 2019-11-09 09:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 12120 2019-11-09 10:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 12180 2019-11-09 11:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 12240 2019-11-09 12:00:00+00:00
# Total: 76, Open: 59, Close: 16
# 12300 2019-11-09 13:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 12360 2019-11-09 14:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 12420 2019-11-09 15:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 12480 2019-11-09 16:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 12540 2019-11-09 17:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 12600 2019-11-09 18:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 12660 2019-11-09 19:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 12720 2019-11-09 20:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 12780 2019-11-09 21:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 12840 2019-11-09 22:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 12900 2019-11-09 23:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 12960 2019-11-10 00:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 13020 2019-11-10 01:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 13080 2019-11-10 02:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 13140 2019-11-10 03:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 13200 2019-11-10 04:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 13260 2019-11-10 05:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 13320 2019-11-10 06:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 13380 2019-11-10 07:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 13440 2019-11-10 08:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 13500 2019-11-10 09:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 13560 2019-11-10 10:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 13620 2019-11-10 11:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 13680 2019-11-10 12:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 13740 2019-11-10 13:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 13800 2019-11-10 14:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 13860 2019-11-10 15:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 13920 2019-11-10 16:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 13980 2019-11-10 17:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 14040 2019-11-10 18:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 14100 2019-11-10 19:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 14160 2019-11-10 20:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 14220 2019-11-10 21:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 14280 2019-11-10 22:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 14340 2019-11-10 23:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 14400 2019-11-11 00:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 14460 2019-11-11 01:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 14520 2019-11-11 02:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 14580 2019-11-11 03:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 14640 2019-11-11 04:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 14700 2019-11-11 05:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 14760 2019-11-11 06:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 14820 2019-11-11 07:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 14880 2019-11-11 08:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 14940 2019-11-11 09:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 15000 2019-11-11 10:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 15060 2019-11-11 11:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 15120 2019-11-11 12:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 15180 2019-11-11 13:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 15240 2019-11-11 14:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 15300 2019-11-11 15:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 15360 2019-11-11 16:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 15420 2019-11-11 17:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 15480 2019-11-11 18:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 15540 2019-11-11 19:00:00+00:00
# Total: 76, Open: 20, Close: 55
# 15600 2019-11-11 20:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 15660 2019-11-11 21:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 15720 2019-11-11 22:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 15780 2019-11-11 23:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 15840 2019-11-12 00:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 15900 2019-11-12 01:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 15960 2019-11-12 02:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 16020 2019-11-12 03:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 16080 2019-11-12 04:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 16140 2019-11-12 05:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 16200 2019-11-12 06:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 16260 2019-11-12 07:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 16320 2019-11-12 08:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 16380 2019-11-12 09:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 16440 2019-11-12 10:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 16500 2019-11-12 11:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 16560 2019-11-12 12:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 16620 2019-11-12 13:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 16680 2019-11-12 14:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 16740 2019-11-12 15:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 16800 2019-11-12 16:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 16860 2019-11-12 17:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 16920 2019-11-12 18:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 16980 2019-11-12 19:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 17040 2019-11-12 20:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 17100 2019-11-12 21:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 17160 2019-11-12 22:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 17220 2019-11-12 23:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 17280 2019-11-13 00:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 17340 2019-11-13 01:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 17400 2019-11-13 02:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 17460 2019-11-13 03:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 17520 2019-11-13 04:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 17580 2019-11-13 05:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 17640 2019-11-13 06:00:00+00:00
# Total: 76, Open: 22, Close: 53
# 17700 2019-11-13 07:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 17760 2019-11-13 08:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 17820 2019-11-13 09:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 17880 2019-11-13 10:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 17940 2019-11-13 11:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 18000 2019-11-13 12:00:00+00:00
# Total: 76, Open: 57, Close: 18
# 18060 2019-11-13 13:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 18120 2019-11-13 14:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 18180 2019-11-13 15:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 18240 2019-11-13 16:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 18300 2019-11-13 17:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 18360 2019-11-13 18:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 18420 2019-11-13 19:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 18480 2019-11-13 20:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 18540 2019-11-13 21:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 18600 2019-11-13 22:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 18660 2019-11-13 23:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 18720 2019-11-14 00:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 18780 2019-11-14 01:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 18840 2019-11-14 02:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 18900 2019-11-14 03:00:00+00:00
# Total: 76, Open: 34, Close: 42
# 18960 2019-11-14 04:00:00+00:00
# Total: 76, Open: 33, Close: 43
# 19020 2019-11-14 05:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 19080 2019-11-14 06:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 19140 2019-11-14 07:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 19200 2019-11-14 08:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 19260 2019-11-14 09:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 19320 2019-11-14 10:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 19380 2019-11-14 11:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 19440 2019-11-14 12:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 19500 2019-11-14 13:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 19560 2019-11-14 14:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 19620 2019-11-14 15:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 19680 2019-11-14 16:00:00+00:00
# Total: 76, Open: 17, Close: 59
# 19740 2019-11-14 17:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 19800 2019-11-14 18:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 19860 2019-11-14 19:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 19920 2019-11-14 20:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 19980 2019-11-14 21:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 20040 2019-11-14 22:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 20100 2019-11-14 23:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 20160 2019-11-15 00:00:00+00:00
# Total: 76, Open: 33, Close: 42
# 20220 2019-11-15 01:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 20280 2019-11-15 02:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 20340 2019-11-15 03:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 20400 2019-11-15 04:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 20460 2019-11-15 05:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 20520 2019-11-15 06:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 20580 2019-11-15 07:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 20640 2019-11-15 08:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 20700 2019-11-15 09:00:00+00:00
# Total: 76, Open: 19, Close: 57
# 20760 2019-11-15 10:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 20820 2019-11-15 11:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 20880 2019-11-15 12:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 20940 2019-11-15 13:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 21000 2019-11-15 14:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 21060 2019-11-15 15:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 21120 2019-11-15 16:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 21180 2019-11-15 17:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 21240 2019-11-15 18:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 21300 2019-11-15 19:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 21360 2019-11-15 20:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 21420 2019-11-15 21:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 21480 2019-11-15 22:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 21540 2019-11-15 23:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 21600 2019-11-16 00:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 21660 2019-11-16 01:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 21720 2019-11-16 02:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 21780 2019-11-16 03:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 21840 2019-11-16 04:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 21900 2019-11-16 05:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 21960 2019-11-16 06:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 22020 2019-11-16 07:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 22080 2019-11-16 08:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 22140 2019-11-16 09:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 22200 2019-11-16 10:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 22260 2019-11-16 11:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 22320 2019-11-16 12:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 22380 2019-11-16 13:00:00+00:00
# Total: 76, Open: 50, Close: 25
# 22440 2019-11-16 14:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 22500 2019-11-16 15:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 22560 2019-11-16 16:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 22620 2019-11-16 17:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 22680 2019-11-16 18:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 22740 2019-11-16 19:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 22800 2019-11-16 20:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 22860 2019-11-16 21:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 22920 2019-11-16 22:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 22980 2019-11-16 23:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 23040 2019-11-17 00:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 23100 2019-11-17 01:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 23160 2019-11-17 02:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 23220 2019-11-17 03:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 23280 2019-11-17 04:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 23340 2019-11-17 05:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 23400 2019-11-17 06:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 23460 2019-11-17 07:00:00+00:00
# Total: 76, Open: 44, Close: 31
# 23520 2019-11-17 08:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 23580 2019-11-17 09:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 23640 2019-11-17 10:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 23700 2019-11-17 11:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 23760 2019-11-17 12:00:00+00:00
# Total: 76, Open: 40, Close: 35
# 23820 2019-11-17 13:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 23880 2019-11-17 14:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 23940 2019-11-17 15:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 24000 2019-11-17 16:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 24060 2019-11-17 17:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 24120 2019-11-17 18:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 24180 2019-11-17 19:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 24240 2019-11-17 20:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 24300 2019-11-17 21:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 24360 2019-11-17 22:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 24420 2019-11-17 23:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 24480 2019-11-18 00:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 24540 2019-11-18 01:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 24600 2019-11-18 02:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 24660 2019-11-18 03:00:00+00:00
# Total: 76, Open: 17, Close: 59
# 24720 2019-11-18 04:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 24780 2019-11-18 05:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 24840 2019-11-18 06:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 24900 2019-11-18 07:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 24960 2019-11-18 08:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 25020 2019-11-18 09:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 25080 2019-11-18 10:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 25140 2019-11-18 11:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 25200 2019-11-18 12:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 25260 2019-11-18 13:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 25320 2019-11-18 14:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 25380 2019-11-18 15:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 25440 2019-11-18 16:00:00+00:00
# Total: 76, Open: 14, Close: 61
# 25500 2019-11-18 17:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 25560 2019-11-18 18:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 25620 2019-11-18 19:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 25680 2019-11-18 20:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 25740 2019-11-18 21:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 25800 2019-11-18 22:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 25860 2019-11-18 23:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 25920 2019-11-19 00:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 25980 2019-11-19 01:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 26040 2019-11-19 02:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 26100 2019-11-19 03:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 26160 2019-11-19 04:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 26220 2019-11-19 05:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 26280 2019-11-19 06:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 26340 2019-11-19 07:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 26400 2019-11-19 08:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 26460 2019-11-19 09:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 26520 2019-11-19 10:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 26580 2019-11-19 11:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 26640 2019-11-19 12:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 26700 2019-11-19 13:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 26760 2019-11-19 14:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 26820 2019-11-19 15:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 26880 2019-11-19 16:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 26940 2019-11-19 17:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 27000 2019-11-19 18:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 27060 2019-11-19 19:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 27120 2019-11-19 20:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 27180 2019-11-19 21:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 27240 2019-11-19 22:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 27300 2019-11-19 23:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 27360 2019-11-20 00:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 27420 2019-11-20 01:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 27480 2019-11-20 02:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 27540 2019-11-20 03:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 27600 2019-11-20 04:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 27660 2019-11-20 05:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 27720 2019-11-20 06:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 27780 2019-11-20 07:00:00+00:00
# Total: 76, Open: 59, Close: 17
# 27840 2019-11-20 08:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 27900 2019-11-20 09:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 27960 2019-11-20 10:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 28020 2019-11-20 11:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 28080 2019-11-20 12:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 28140 2019-11-20 13:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 28200 2019-11-20 14:00:00+00:00
# Total: 76, Open: 19, Close: 56
# 28260 2019-11-20 15:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 28320 2019-11-20 16:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 28380 2019-11-20 17:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 28440 2019-11-20 18:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 28500 2019-11-20 19:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 28560 2019-11-20 20:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 28620 2019-11-20 21:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 28680 2019-11-20 22:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 28740 2019-11-20 23:00:00+00:00
# Total: 76, Open: 12, Close: 64
# 28800 2019-11-21 00:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 28860 2019-11-21 01:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 28920 2019-11-21 02:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 28980 2019-11-21 03:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 29040 2019-11-21 04:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 29100 2019-11-21 05:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 29160 2019-11-21 06:00:00+00:00
# Total: 76, Open: 29, Close: 47
# 29220 2019-11-21 07:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 29280 2019-11-21 08:00:00+00:00
# Total: 76, Open: 17, Close: 59
# 29340 2019-11-21 09:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 29400 2019-11-21 10:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 29460 2019-11-21 11:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 29520 2019-11-21 12:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 29580 2019-11-21 13:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 29640 2019-11-21 14:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 29700 2019-11-21 15:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 29760 2019-11-21 16:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 29820 2019-11-21 17:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 29880 2019-11-21 18:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 29940 2019-11-21 19:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 30000 2019-11-21 20:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 30060 2019-11-21 21:00:00+00:00
# Total: 76, Open: 1, Close: 75
# 30120 2019-11-21 22:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 30180 2019-11-21 23:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 30240 2019-11-22 00:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 30300 2019-11-22 01:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 30360 2019-11-22 02:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 30420 2019-11-22 03:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 30480 2019-11-22 04:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 30540 2019-11-22 05:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 30600 2019-11-22 06:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 30660 2019-11-22 07:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 30720 2019-11-22 08:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 30780 2019-11-22 09:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 30840 2019-11-22 10:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 30900 2019-11-22 11:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 30960 2019-11-22 12:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 31020 2019-11-22 13:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 31080 2019-11-22 14:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 31140 2019-11-22 15:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 31200 2019-11-22 16:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 31260 2019-11-22 17:00:00+00:00
# Total: 76, Open: 1, Close: 75
# 31320 2019-11-22 18:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 31380 2019-11-22 19:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 31440 2019-11-22 20:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 31500 2019-11-22 21:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 31560 2019-11-22 22:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 31620 2019-11-22 23:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 31680 2019-11-23 00:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 31740 2019-11-23 01:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 31800 2019-11-23 02:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 31860 2019-11-23 03:00:00+00:00
# Total: 76, Open: 19, Close: 57
# 31920 2019-11-23 04:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 31980 2019-11-23 05:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 32040 2019-11-23 06:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 32100 2019-11-23 07:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 32160 2019-11-23 08:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 32220 2019-11-23 09:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 32280 2019-11-23 10:00:00+00:00
# Total: 76, Open: 24, Close: 52
# 32340 2019-11-23 11:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 32400 2019-11-23 12:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 32460 2019-11-23 13:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 32520 2019-11-23 14:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 32580 2019-11-23 15:00:00+00:00
# Total: 76, Open: 44, Close: 32
# 32640 2019-11-23 16:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 32700 2019-11-23 17:00:00+00:00
# Total: 76, Open: 67, Close: 9
# 32760 2019-11-23 18:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 32820 2019-11-23 19:00:00+00:00
# Total: 76, Open: 71, Close: 5
# 32880 2019-11-23 20:00:00+00:00
# Total: 76, Open: 71, Close: 5
# 32940 2019-11-23 21:00:00+00:00
# Total: 76, Open: 70, Close: 6
# 33000 2019-11-23 22:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 33060 2019-11-23 23:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 33120 2019-11-24 00:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 33180 2019-11-24 01:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 33240 2019-11-24 02:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 33300 2019-11-24 03:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 33360 2019-11-24 04:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 33420 2019-11-24 05:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 33480 2019-11-24 06:00:00+00:00
# Total: 76, Open: 17, Close: 59
# 33540 2019-11-24 07:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 33600 2019-11-24 08:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 33660 2019-11-24 09:00:00+00:00
# Total: 76, Open: 11, Close: 65
# 33720 2019-11-24 10:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 33780 2019-11-24 11:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 33840 2019-11-24 12:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 33900 2019-11-24 13:00:00+00:00
# Total: 76, Open: 19, Close: 57
# 33960 2019-11-24 14:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 34020 2019-11-24 15:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 34080 2019-11-24 16:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 34140 2019-11-24 17:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 34200 2019-11-24 18:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 34260 2019-11-24 19:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 34320 2019-11-24 20:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 34380 2019-11-24 21:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 34440 2019-11-24 22:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 34500 2019-11-24 23:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 34560 2019-11-25 00:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 34620 2019-11-25 01:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 34680 2019-11-25 02:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 34740 2019-11-25 03:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 34800 2019-11-25 04:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 34860 2019-11-25 05:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 34920 2019-11-25 06:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 34980 2019-11-25 07:00:00+00:00
# Total: 76, Open: 6, Close: 70
# 35040 2019-11-25 08:00:00+00:00
# Total: 76, Open: 5, Close: 71
# 35100 2019-11-25 09:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 35160 2019-11-25 10:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 35220 2019-11-25 11:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 35280 2019-11-25 12:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 35340 2019-11-25 13:00:00+00:00
# Total: 76, Open: 46, Close: 30
# 35400 2019-11-25 14:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 35460 2019-11-25 15:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 35520 2019-11-25 16:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 35580 2019-11-25 17:00:00+00:00
# Total: 76, Open: 72, Close: 4
# 35640 2019-11-25 18:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 35700 2019-11-25 19:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 35760 2019-11-25 20:00:00+00:00
# Total: 76, Open: 70, Close: 6
# 35820 2019-11-25 21:00:00+00:00
# Total: 76, Open: 70, Close: 6
# 35880 2019-11-25 22:00:00+00:00
# Total: 76, Open: 70, Close: 6
# 35940 2019-11-25 23:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 36000 2019-11-26 00:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 36060 2019-11-26 01:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 36120 2019-11-26 02:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 36180 2019-11-26 03:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 36240 2019-11-26 04:00:00+00:00
# Total: 76, Open: 56, Close: 20
# 36300 2019-11-26 05:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 36360 2019-11-26 06:00:00+00:00
# Total: 76, Open: 67, Close: 9
# 36420 2019-11-26 07:00:00+00:00
# Total: 76, Open: 67, Close: 9
# 36480 2019-11-26 08:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 36540 2019-11-26 09:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 36600 2019-11-26 10:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 36660 2019-11-26 11:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 36720 2019-11-26 12:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 36780 2019-11-26 13:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 36840 2019-11-26 14:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 36900 2019-11-26 15:00:00+00:00
# Total: 76, Open: 31, Close: 45
# 36960 2019-11-26 16:00:00+00:00
# Total: 76, Open: 34, Close: 42
# 37020 2019-11-26 17:00:00+00:00
# Total: 76, Open: 30, Close: 46
# 37080 2019-11-26 18:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 37140 2019-11-26 19:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 37200 2019-11-26 20:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 37260 2019-11-26 21:00:00+00:00
# Total: 76, Open: 37, Close: 39
# 37320 2019-11-26 22:00:00+00:00
# Total: 76, Open: 36, Close: 40
# 37380 2019-11-26 23:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 37440 2019-11-27 00:00:00+00:00
# Total: 76, Open: 53, Close: 23
# 37500 2019-11-27 01:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 37560 2019-11-27 02:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 37620 2019-11-27 03:00:00+00:00
# Total: 76, Open: 63, Close: 12
# 37680 2019-11-27 04:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 37740 2019-11-27 05:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 37800 2019-11-27 06:00:00+00:00
# Total: 76, Open: 40, Close: 36
# 37860 2019-11-27 07:00:00+00:00
# Total: 76, Open: 28, Close: 48
# 37920 2019-11-27 08:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 37980 2019-11-27 09:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 38040 2019-11-27 10:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 38100 2019-11-27 11:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 38160 2019-11-27 12:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 38220 2019-11-27 13:00:00+00:00
# Total: 76, Open: 18, Close: 58
# 38280 2019-11-27 14:00:00+00:00
# Total: 76, Open: 20, Close: 56
# 38340 2019-11-27 15:00:00+00:00
# Total: 76, Open: 47, Close: 29
# 38400 2019-11-27 16:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 38460 2019-11-27 17:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 38520 2019-11-27 18:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 38580 2019-11-27 19:00:00+00:00
# Total: 76, Open: 68, Close: 8
# 38640 2019-11-27 20:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 38700 2019-11-27 21:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 38760 2019-11-27 22:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 38820 2019-11-27 23:00:00+00:00
# Total: 76, Open: 69, Close: 7
# 38880 2019-11-28 00:00:00+00:00
# Total: 76, Open: 67, Close: 9
# 38940 2019-11-28 01:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 39000 2019-11-28 02:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 39060 2019-11-28 03:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 39120 2019-11-28 04:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 39180 2019-11-28 05:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 39240 2019-11-28 06:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 39300 2019-11-28 07:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 39360 2019-11-28 08:00:00+00:00
# Total: 76, Open: 50, Close: 26
# 39420 2019-11-28 09:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 39480 2019-11-28 10:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 39540 2019-11-28 11:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 39600 2019-11-28 12:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 39660 2019-11-28 13:00:00+00:00
# Total: 76, Open: 45, Close: 31
# 39720 2019-11-28 14:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 39780 2019-11-28 15:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 39840 2019-11-28 16:00:00+00:00
# Total: 76, Open: 41, Close: 35
# 39900 2019-11-28 17:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 39960 2019-11-28 18:00:00+00:00
# Total: 76, Open: 60, Close: 16
# 40020 2019-11-28 19:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 40080 2019-11-28 20:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 40140 2019-11-28 21:00:00+00:00
# Total: 76, Open: 61, Close: 15
# 40200 2019-11-28 22:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 40260 2019-11-28 23:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 40320 2019-11-29 00:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 40380 2019-11-29 01:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 40440 2019-11-29 02:00:00+00:00
# Total: 76, Open: 19, Close: 57
# 40500 2019-11-29 03:00:00+00:00
# Total: 76, Open: 16, Close: 60
# 40560 2019-11-29 04:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 40620 2019-11-29 05:00:00+00:00
# Total: 76, Open: 27, Close: 49
# 40680 2019-11-29 06:00:00+00:00
# Total: 76, Open: 25, Close: 51
# 40740 2019-11-29 07:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 40800 2019-11-29 08:00:00+00:00
# Total: 76, Open: 34, Close: 41
# 40860 2019-11-29 09:00:00+00:00
# Total: 76, Open: 35, Close: 41
# 40920 2019-11-29 10:00:00+00:00
# Total: 76, Open: 43, Close: 33
# 40980 2019-11-29 11:00:00+00:00
# Total: 76, Open: 55, Close: 21
# 41040 2019-11-29 12:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 41100 2019-11-29 13:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 41160 2019-11-29 14:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 41220 2019-11-29 15:00:00+00:00
# Total: 76, Open: 66, Close: 10
# 41280 2019-11-29 16:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 41340 2019-11-29 17:00:00+00:00
# Total: 76, Open: 64, Close: 12
# 41400 2019-11-29 18:00:00+00:00
# Total: 76, Open: 65, Close: 11
# 41460 2019-11-29 19:00:00+00:00
# Total: 76, Open: 63, Close: 13
# 41520 2019-11-29 20:00:00+00:00
# Total: 76, Open: 62, Close: 14
# 41580 2019-11-29 21:00:00+00:00
# Total: 76, Open: 58, Close: 18
# 41640 2019-11-29 22:00:00+00:00
# Total: 76, Open: 57, Close: 19
# 41700 2019-11-29 23:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 41760 2019-11-30 00:00:00+00:00
# Total: 76, Open: 51, Close: 25
# 41820 2019-11-30 01:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 41880 2019-11-30 02:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 41940 2019-11-30 03:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 42000 2019-11-30 04:00:00+00:00
# Total: 76, Open: 42, Close: 34
# 42060 2019-11-30 05:00:00+00:00
# Total: 76, Open: 38, Close: 38
# 42120 2019-11-30 06:00:00+00:00
# Total: 76, Open: 32, Close: 44
# 42180 2019-11-30 07:00:00+00:00
# Total: 76, Open: 23, Close: 52
# 42240 2019-11-30 08:00:00+00:00
# Total: 76, Open: 23, Close: 53
# 42300 2019-11-30 09:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 42360 2019-11-30 10:00:00+00:00
# Total: 76, Open: 22, Close: 54
# 42420 2019-11-30 11:00:00+00:00
# Total: 76, Open: 21, Close: 55
# 42480 2019-11-30 12:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 42540 2019-11-30 13:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 42600 2019-11-30 14:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 42660 2019-11-30 15:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 42720 2019-11-30 16:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 42780 2019-11-30 17:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 42840 2019-11-30 18:00:00+00:00
# Total: 76, Open: 15, Close: 61
# 42900 2019-11-30 19:00:00+00:00
# Total: 76, Open: 14, Close: 62
# 42960 2019-11-30 20:00:00+00:00
# Total: 76, Open: 13, Close: 63
# 43020 2019-11-30 21:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 43080 2019-11-30 22:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 43140 2019-11-30 23:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 43200 2019-12-01 00:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 43260 2019-12-01 01:00:00+00:00
# Total: 76, Open: 9, Close: 67
# 43320 2019-12-01 02:00:00+00:00
# Total: 76, Open: 8, Close: 68
# 43380 2019-12-01 03:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 43440 2019-12-01 04:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 43500 2019-12-01 05:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 43560 2019-12-01 06:00:00+00:00
# Total: 76, Open: 1, Close: 75
# 43620 2019-12-01 07:00:00+00:00
# Total: 76, Open: 1, Close: 75
# 43680 2019-12-01 08:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 43740 2019-12-01 09:00:00+00:00
# Total: 76, Open: 3, Close: 73
# 43800 2019-12-01 10:00:00+00:00
# Total: 76, Open: 2, Close: 74
# 43860 2019-12-01 11:00:00+00:00
# Total: 76, Open: 4, Close: 72
# 43920 2019-12-01 12:00:00+00:00
# Total: 76, Open: 7, Close: 69
# 43980 2019-12-01 13:00:00+00:00
# Total: 76, Open: 10, Close: 66
# 44040 2019-12-01 14:00:00+00:00
# Total: 76, Open: 26, Close: 50
# 44100 2019-12-01 15:00:00+00:00
# Total: 76, Open: 34, Close: 42
# 44160 2019-12-01 16:00:00+00:00
# Total: 76, Open: 39, Close: 37
# 44220 2019-12-01 17:00:00+00:00
# Total: 76, Open: 49, Close: 27
# 44280 2019-12-01 18:00:00+00:00
# Total: 76, Open: 52, Close: 24
# 44340 2019-12-01 19:00:00+00:00
# Total: 76, Open: 48, Close: 28
# 44400 2019-12-01 20:00:00+00:00
# Total: 76, Open: 48, Close: 27
# 44460 2019-12-01 21:00:00+00:00
# Total: 76, Open: 54, Close: 22
# 44520 2019-12-01 22:00:00+00:00
# Total: 76, Open: 56, Close: 19
# 44580 2019-12-01 23:00:00+00:00
# Total: 76, Open: 56, Close: 20
# [2019-12-05 18:41:23.836241] INFO: Performance: Simulated 31 trading days out of 31.
# [2019-12-05 18:41:23.836830] INFO: Performance: first open: 2019-11-01 00:00:00+00:00
# [2019-12-05 18:41:23.837297] INFO: Performance: last close: 2019-12-01 23:59:00+00:00
